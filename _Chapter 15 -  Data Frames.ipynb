# %%
import  numpy as np

import pandas as pd

from pandas import Series,DataFrame

# %%
# Example 1  - importing  NFL dat from website

# %%
import webbrowser
NFL_data='http://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
webbrowser.open(NFL_data)
# Out:
# True

# %%
# copying data will outmatically copy to clipboard

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
# sample pulling out column name
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Team # pulling out data for column Team-
# Out:
# 0       Green Bay Packers
# 1          Dallas Cowboys
# 2        Baltimore Ravens
# 3           Chicago Bears
# 4    New England Patriots
# Name: Team, dtype: object

# %%
 # But this wont work out with columns that 
 #have more than one word in it Example ('First NFL season'). in this case use brackets as below

# %%
nfl_frame['First NFL season']
# Out:
# 0    1921
# 1    1960
# 2    1996
# 3    1920
# 4    1960
# Name: First NFL season, dtype: int64

# %%
# Samele  2  - Pulling out Multiple columns, this can be done by creating now data frame

DataFrame(nfl_frame,columns= ['First NFL season','Rank', 'Team','Won', 'Lost', 'Tied'])
# Out:
#    First NFL season  Rank                  Team  Won  Lost  Tied
# 0              1921     1     Green Bay Packers  769   577    38
# 1              1960     2        Dallas Cowboys  526   398     6
# 2              1996     3      Baltimore Ravens  225   174     1
# 3              1920     4         Chicago Bears  777   599    42
# 4              1960     5  New England Patriots  519   404     9

# %%
# Example 2  - How to  pull rows of data frame, head and  tail  function

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
nfl_frame.head(4) # Head () with  no of rows mention in bracket will  pull out  first 4  rows of the  data frame
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL season  \
# 0     1  Green Bay Packers  1,384  769   577    38  0.569              1921
# 1     2     Dallas Cowboys    930  526   398     6  0.569              1960
# 2     3   Baltimore Ravens    400  225   174     1  0.564              1996
# 3     4      Chicago Bears  1,418  777   599    42  0.563              1920
#
#     Division
# 0  NFC North
# 1   NFC East
# 2  AFC North
# 3  NFC North

# %%
nfl_frame.tail(2) # tail (2), tail function with  no of rows mention within bracket will pull out mentioned no of rows from  bottom of the data frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 3              1920  NFC North
# 4              1960   AFC East

# %%
# sample  1 - Retriving  rows on paticular index

# %%
nfl_frame.iloc[2]
# Out:
# Rank                               3
# Team                Baltimore Ravens
# GP                               400
# Won                              225
# Lost                             174
# Tied                               1
# Pct.                           0.564
# First NFL season                1996
# Division                   AFC North
# Name: 2, dtype: object

# %%
# Example 3 - Assiginig values to entier column

# %%
# sample 1
nfl_frame['Division'] = 'North East'
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season    Division    Dividion
# 0              1921  North East  North East
# 1              1960  North East  North East
# 2              1996  North East  North East
# 3              1920  North East  North East
# 4              1960  North East  North East

# %%
#sample 2
nfl_frame['Dividion'] = np.arange(5)
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season    Division  Dividion
# 0              1921  North East         0
# 1              1960  North East         1
# 2              1996  North East         2
# 3              1920  North East         3
# 4              1960  North East         4

# %%
# sample 3
# craeting a series and then assigning it to data frame

Dividions = Series(["South","State", "central"], index=[4,0,2])

# %%
Dividions
# Out:
# 4      South
# 0      State
# 2    central
# dtype: object

# %%
nfl_frame['Dividion']  = Dividions
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season    Division Dividion
# 0              1921  North East    State
# 1              1960  North East      NaN
# 2              1996  North East  central
# 3              1920  North East      NaN
# 4              1960  North East    South

# %%
# Example 4 - Deliting  Columns

del nfl_frame['Dividion']
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season    Division
# 0              1921  North East
# 1              1960  North East
# 2              1996  North East
# 3              1920  North East
# 4              1960  North East

# %%
# Example 5  - Constructing  Date Frame by passsing in Dictionaries

# %%
population = {'city':['che','mum','hyd'], 'population':[4.6,7.8,9.4]}

# %%
City_popu = DataFrame(population)

# %%
City_popu
# Out:
#   city  population
# 0  che         4.6
# 1  mum         7.8
# 2  hyd         9.4
